# %%
##importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load dataset

df = pd.read_csv("EPL_20_21.csv")

# %%
df
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %%
df.info()
#this is basically getting me info of columns that are present
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 532 entries, 0 to 531
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   532 non-null    object
#  1   Club                   532 non-null    object
#  2   Nationality            532 non-null    object
#  3   Position               532 non-null    object
#  4   Age                    532 non-null    int64
#  5   Matches                532 non-null    int64
#  6   Starts                 532 non-null    int64
#  7   Mins                   532 non-null    int64
#  8   Goals                  532 non-null    int64
#  9   Assists                532 non-null    int64
#  10  Passes_Attempted       532 non-null    int64
#  11  Perc_Passes_Completed  532 non-null    float64
#  12  Penalty_Goals          532 non-null    int64
#  13  Penalty_Attempted      532 non-null    int64
# ...

# %%
df.describe()
#can giv me a over view of things there like Avg standard deviation and respective percentages that lie above
# Out:
#               Age     Matches      Starts         Mins       Goals  \
# count  532.000000  532.000000  532.000000   532.000000  532.000000
# mean    25.500000   19.535714   15.714286  1411.443609    1.853383
# std      4.319404   11.840459   11.921161  1043.171856    3.338009
# min     16.000000    1.000000    0.000000     1.000000    0.000000
# 25%     22.000000    9.000000    4.000000   426.000000    0.000000
# 50%     26.000000   21.000000   15.000000  1345.000000    1.000000
# 75%     29.000000   30.000000   27.000000  2303.500000    2.000000
# max     38.000000   38.000000   38.000000  3420.000000   23.000000
#
#           Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# count  532.000000        532.000000             532.000000     532.000000
# mean     1.287594        717.750000              77.823872       0.191729
# std      2.095191        631.372522              13.011631       0.850881
# ...

# %%
df.isna().sum()
#there are no null values in shirt number
# Out:
# Name                     0
# Club                     0
# Nationality              0
# Position                 0
# Age                      0
# Matches                  0
# Starts                   0
# Mins                     0
# Goals                    0
# Assists                  0
# Passes_Attempted         0
# Perc_Passes_Completed    0
# Penalty_Goals            0
# Penalty_Attempted        0
# xG                       0
# xA                       0
# Yellow_Cards             0
# Red_Cards                0
# dtype: int64

# %%
#i need two more columns for this data to be precised
df["Minspermatch"] = (df["Mins"]/df["Matches"]).astype(int)
df["Goalspermatch"] = (df["Goals"]/df["Matches"]).astype(float)

# %%
#as you can see two columns had included in this data set
df.tail(20)
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 512     Oliver Norwood  Sheffield United         NIR       MF   29       32
# 513       Ethan Ampadu  Sheffield United         WAL    DF,MF   19       25
# 514     John Lundstram  Sheffield United         ENG       MF   26       28
# 515         Ben Osborn  Sheffield United         ENG    MF,DF   25       24
# 516       Oliver Burke  Sheffield United         SCO       FW   23       25
# 517       Sander Berge  Sheffield United         NOR       MF   22       15
# 518    Oliver McBurnie  Sheffield United         SCO       FW   24       23
# 519     Rhian Brewster  Sheffield United         ENG       FW   20       27
# 520       Jayden Bogle  Sheffield United         ENG       DF   20       16
# 521         Kean Bryan  Sheffield United         ENG       DF   23       13
# 522      Jack Robinson  Sheffield United         ENG       DF   26       11
# ...

# %%
#total goals for this season
total_goals=df["Goals"].sum()
print(total_goals)
# Out:
# 986

# %%
#total assists
total_assists = df["Assists"].sum()
print(total_assists)
# Out:
# 685

# %%
#total penalty goals
total_penalty_goals = df["Penalty_Goals"].sum()
print(total_penalty_goals)
# Out:
# 102

# %%
#piechart for the penalties scored vs missed
plt.figure(figsize=(7,5))
pl_not_scored = df["Penalty_Attempted"].sum() - total_penalty_goals
data = [pl_not_scored,total_penalty_goals]
labels = [ "missed", "Penalties scored"]
color = sns.color_palette("tab10")
plt.pie(data, labels = labels, colors = color ,autopct= "%.0f%%")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#lets find their positions like defensive midfielder,striker etc (unique positionm)
df["Position"].unique()
# Out:
# array(['MF,FW', 'GK', 'FW', 'DF', 'MF', 'FW,MF', 'FW,DF', 'DF,MF',
#        'MF,DF', 'DF,FW'], dtype=object)

# %%
#total strikers
df[df["Position"] == "FW"]
# Out:
#                    Name              Club Nationality Position  Age  Matches  \
# 2           Timo Werner           Chelsea         GER       FW   24       35
# 16        Tammy Abraham           Chelsea         ENG       FW   22       22
# 19       Olivier Giroud           Chelsea         FRA       FW   33       17
# 23   Ruben Loftus-Cheek           Chelsea         ENG       FW   24        1
# 30      Raheem Sterling   Manchester City         ENG       FW   25       31
# ..                  ...               ...         ...      ...  ...      ...
# 516        Oliver Burke  Sheffield United         SCO       FW   23       25
# 518     Oliver McBurnie  Sheffield United         SCO       FW   24       23
# 519      Rhian Brewster  Sheffield United         ENG       FW   20       27
# 523         Billy Sharp  Sheffield United         ENG       FW   34       16
# 526     Daniel Jebbison  Sheffield United         ENG       FW   17        4
#
# ...

# %%
max_goals_player = df[df['Goals'] == df['Goals'].max()]['Name'].iloc[0]
max_goals = df['Goals'].max()
plt.figure(figsize=(5, 2))
plt.bar(max_goals_player, max_goals, color='blue')
plt.xlabel('Player')
plt.ylabel('Goals')
plt.title('Player with Maximum Goals')
plt.xticks(rotation=45)
plt.tight_layout()
plt.text(max_goals_player, max_goals + 0.5, f'{max_goals}', ha='center')
plt.show()
###here basically u can see tht harry kane was the top scorer from tottenham

# %%
max_assist_player = df[df['Assists'] == df['Assists'].max()]['Name'].iloc[0]
max_assists = df['Assists'].max()
plt.figure(figsize=(5,2))
plt.bar(max_assist_player, max_assists, color='green')
plt.xlabel('Player')
plt.ylabel('assist')
plt.title('Player with maximum assists')
plt.xticks(rotation=45)
plt.tight_layout()
plt.text(max_assist_player,max_assists  + 0.5, f'{max_assists}', ha='center')
plt.show()
#one season wonder Harry kane also having highest assists

# %%
#
nationality = df.groupby('Nationality').size().sort_values(ascending = False)
nationality.head(10).plot(kind= "bar", figsize = (12,5) , color = sns.color_palette("magma"))
plt.title("highest country players", fontsize=15)
#as we can see most of the players are from England (english premier league)
# Out:
# Text(0.5, 1.0, 'highest country players')

# %%
#clubs with maximum players intheir squad
df["Club"].value_counts().nlargest(5).plot(kind = "bar" , color = sns.color_palette("magma"))
#ans=westbrom stands around 30 players including reserves
# Out:
# <Axes: >

# %%
#clubs with minimum players
df["Club"].value_counts().nsmallest(5).plot(kind = "bar" , color = sns.color_palette("viridis"))
#as we hav seen leeds united and man city hav the least amount of players
#also we know it will be tough for leeds as marcelo bielsa pressurizes their player for high intensity training
# Out:
# <Axes: >

# %%
under20= df[df["Age"] <= 20]
under20_25= df[(df["Age"] > 20) & (df ["Age"] <= 25)]
under25_30= df[(df["Age"] > 25) & (df ["Age"] <= 30)]
above30= df[df["Age"] > 30]

# %%
x = np.array([under20['Name'].count(),under20_25["Name"].count(),under25_30["Name"].count(),above30["Name"].count()])
mylabels = ["<=20",">20 & <=25",">25 & <=30", ">30"]
plt.title("Total players with age group", fontsize=15)
plt.pie(x,labels = mylabels , autopct = "%.1f%%")
plt.show()
#here are basically i found that maximum age group is under 20 to 30 its an competitive league

# %%
#most youngsters in a club lets say less then 22 years of age
players_underage_22 = df[df[ "Age"] < 22]
players_underage_22["Club"].value_counts().plot(kind = 'bar', color = sns.color_palette("magma"))
plt.title("age under 22", fontsize=15)
#here basically southampton wolves brighton hav better youngsters
# Out:
# Text(0.5, 1.0, 'age under 22')

# %%
#i personally love chelsea so players under 22 age on that club
players_underage_22[players_underage_22["Club"] == "Chelsea"]
# Out:
#                   Name     Club Nationality Position  Age  Matches  Starts  \
# 0          Mason Mount  Chelsea         ENG    MF,FW   21       36      32
# 4          Reece James  Chelsea         ENG       DF   20       32      25
# 12   Christian Pulisic  Chelsea         USA    FW,MF   21       27      18
# 13         Kai Havertz  Chelsea         GER    MF,FW   21       27      18
# 18  Callum Hudson-Odoi  Chelsea         ENG    FW,DF   19       23      10
# 21       Billy Gilmour  Chelsea         SCO       MF   19        5       3
#
#     Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 0   2890      6        5              1881                   82.3
# 4   2373      1        2              1987                   85.0
# 12  1738      4        2               690                   80.0
# 13  1520      4        3               765                   86.1
# 18  1059      2        3               659                   82.2
# ...

# %%
#Avg age of each club
plt.figure(figsize = (12,6))
sns.boxplot( x = "Club", y = "Age" , data = df)
plt.xticks(rotation=90)
plt.title("age",fontsize = 15)
# Out:
# Text(0.5, 1.0, 'age')

# %%
#top 10 assist provider for season (20-21)
top_10_assists = df[["Name" ,"Club" ,"Assists", "Matches"]].nlargest( n=10 ,columns = "Assists")
top_10_assists
#i personally like de bruyne wow wht a player
# Out:
#                      Name               Club  Assists  Matches
# 162            Harry Kane  Tottenham Hotspur       14       35
# 34        Kevin De Bruyne    Manchester City       12       25
# 51        Bruno Fernandes  Manchester United       12       37
# 161         Son Heung-min  Tottenham Hotspur       10       37
# 273         Jack Grealish        Aston Villa       10       26
# 54        Marcus Rashford  Manchester United        9       37
# 110           Jamie Vardy     Leicester City        9       34
# 220  Raphael Dias Belloli       Leeds United        9       30
# 2             Timo Werner            Chelsea        8       35
# 136       Aaron Cresswell    West Ham United        8       36

# %%
#goals scored by each club for this season
Goals_byclubs = pd.DataFrame(df.groupby("Club" , as_index =False)['Goals'].sum())
sns.set_theme(style="darkgrid",color_codes = True)
ax = sns.barplot(x="Club",y="Goals",data = Goals_byclubs.sort_values(by="Goals"),palette="rocket")
ax.set_xlabel("Club",fontsize=30)
ax.set_ylabel("Goals",fontsize=20)
plt.xticks(rotation=75)
plt.rcParams["figure.figsize"] = (20,8)
plt.title("clubs total goals" , fontsize=20)
# Out:
# Text(0.5, 1.0, 'clubs total goals')

# %%
#top 10 goalscorers
top_10_goals =df[["Name", "Club", "Goals", "Matches"]].nlargest(n=10,columns="Goals")
top_10_goals
# Out:
#                       Name               Club  Goals  Matches
# 162             Harry Kane  Tottenham Hotspur     23       35
# 81           Mohamed Salah       Liverpool FC     22       37
# 51         Bruno Fernandes  Manchester United     18       37
# 161          Son Heung-min  Tottenham Hotspur     17       37
# 214        Patrick Bamford       Leeds United     17       38
# 237  Dominic Calvert-Lewin            Everton     16       33
# 110            Jamie Vardy     Leicester City     15       34
# 267          Ollie Watkins        Aston Villa     14       37
# 33          İlkay Gündoğan    Manchester City     13       28
# 191    Alexandre Lacazette            Arsenal     13       31

# %%
#lets talk about who has the highest goal scoring ratio
top_10_goals =df[["Name", "Club", "Goals", "Matches", "Goalspermatch"]].nlargest(n=10,columns="Goals")
top_10_goals
# Out:
#                       Name               Club  Goals  Matches  Goalspermatch
# 162             Harry Kane  Tottenham Hotspur     23       35       0.657143
# 81           Mohamed Salah       Liverpool FC     22       37       0.594595
# 51         Bruno Fernandes  Manchester United     18       37       0.486486
# 161          Son Heung-min  Tottenham Hotspur     17       37       0.459459
# 214        Patrick Bamford       Leeds United     17       38       0.447368
# 237  Dominic Calvert-Lewin            Everton     16       33       0.484848
# 110            Jamie Vardy     Leicester City     15       34       0.441176
# 267          Ollie Watkins        Aston Villa     14       37       0.378378
# 33          İlkay Gündoğan    Manchester City     13       28       0.464286
# 191    Alexandre Lacazette            Arsenal     13       31       0.419355

# %%
total_yellow_card = df.sort_values(by="Yellow_Cards",ascending = False)[:10]
plt.figure(figsize=(20,6))
plt.title("players with the most yellow cards")
c = sns.barplot(x=total_yellow_card["Name"], y=total_yellow_card["Yellow_Cards"], label="Players", color="yellow")
plt.ylabel("No of yellow cards")
c.set_xticklabels(c.get_xticklabels(), rotation=45)
c
# Out:
# <Axes: title={'center': 'players with the most yellow cards'}, xlabel='Name', ylabel='No of yellow cards'>
